# %% [markdown]
# ## Calculating Distances Between Points (Ugandan Cities)

# %%
import geopandas as gpd

# %%
file_path = '/Users/otwiine/Desktop/Cities_2020/Cities_2020.shp'

# %%
distances = gpd.read_file(file_path)

# %%
distances
# Out:
#            NAME Type_of_to         2020                       geometry
# 0        Masaka       City       MASAKA  POINT (359290.384 -36891.576)
# 1        Moroto       City       MOROTO  POINT (684692.519 280166.149)
# 2         Mbale       City        MBALE  POINT (630908.282 119176.976)
# 3   Fort Portal       City     KABAROLE   POINT (197284.743 73762.603)
# 4       Mbarara       City      MBARARA  POINT (239547.575 -66944.127)
# 5   Nakasongola       City  NAKASONGOLA  POINT (440474.645 145915.691)
# 6        Soroti       City       SOROTI  POINT (568017.352 189951.867)
# 7        Kabale       City   BUNYANGABU   POINT (187960.482 50298.926)
# 8        Wakiso       City       WAKISO    POINT (441822.848 44299.21)
# 9       Entebbe       City       WAKISO     POINT (441113.075 6913.15)
# 10        Jinja       City        JINJA   POINT (523343.245 47936.776)
# 11         Gulu       City         GULU  POINT (421803.323 307325.558)
# 12         Lira       City         LIRA  POINT (488850.315 248819.338)
# 13      Kampala    Capital      KAMPALA   POINT (452581.416 35435.877)
# 14       Kabale       City       KABALE   POINT (164714.6 -138570.961)
# 15        Hoima       City        HOIMA   POINT (316642.15 158582.264)
# 16         Arua       City         ARUA  POINT (267683.936 334595.081)
